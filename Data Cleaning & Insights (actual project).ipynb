# %% [markdown]
# # I, Data Cleaning

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv(r"C:\Users\t\OneDrive\Desktop\Data Analyst\csc test.csv")

df
# Out:
# C:\Users\t\AppData\Local\Temp\ipykernel_8212\288089847.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\t\OneDrive\Desktop\Data Analyst\csc test.csv")
#             ID Customer_ID     Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...        ...         ...       ...            ...   ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks    25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks    25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks    25  078-73-5990
# ...

# %% [markdown]
# #### Find and replace column 26 into string data type

# %%
column_26 = df.iloc[:, 25]

column_26
# Out:
# 0         High_spent_Small_value_payments
# 1          Low_spent_Large_value_payments
# 2         Low_spent_Medium_value_payments
# 3          Low_spent_Small_value_payments
# 4        High_spent_Medium_value_payments
#                        ...
# 99995     High_spent_Large_value_payments
# 99996    High_spent_Medium_value_payments
# 99997     High_spent_Large_value_payments
# 99998      Low_spent_Large_value_payments
# 99999                              !@9#%8
# Name: Payment_Behaviour, Length: 100000, dtype: object

# %%
df['Payment_Behaviour'] = df['Payment_Behaviour'].astype(str)

df
# Out:
#             ID Customer_ID     Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...        ...         ...       ...            ...   ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks    25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks    25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks    25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks    25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %% [markdown]
# ### 2, Data Cleaning

# %%
df.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                          object
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
# I use excel filter to find special charaters
df['Age'] = df['Age'].str.strip("_-")
df['SSN'] = df['SSN'].str.strip("#F%$D@*&")
df['SSN'] = df['SSN'].str.replace(r'^(8)$','',regex = True)
df['Occupation'] = df['Occupation'].str.strip("_______")
df['Annual_Income'] = df['Annual_Income'].str.strip("_")
df['Num_of_Loan'] = df['Num_of_Loan'].str.strip("_-")
df['Num_of_Delayed_Payment'] = df['Num_of_Delayed_Payment'].str.strip("_")
df['Changed_Credit_Limit'] = df['Changed_Credit_Limit'].str.strip("_")
df['Credit_Mix'] = df['Credit_Mix'].str.strip("_")
df['Outstanding_Debt'] = df['Outstanding_Debt'].str.strip("_")
df['Credit_Mix'] = df['Credit_Mix'].str.strip("_")
df['Payment_of_Min_Amount'] = df['Payment_of_Min_Amount'].str.replace(r'^(NM)$','Not Mentioned',regex = True)
df['Amount_invested_monthly'] = df['Amount_invested_monthly'].str.replace(r'^(__10000__)$','',regex = True)
df['Payment_Behaviour'] = df['Payment_Behaviour'].str.replace(r'^(!@9#%8)$','',regex = True)


df
# Out:
#             ID Customer_ID     Month           Name  Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh   23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh   23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh   23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh   23  821-00-0265
# ...        ...         ...       ...            ...  ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks   25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks   25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks   25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks   25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks   25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name  Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh   23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh   23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh   23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh   23  821-00-0265  Scientist
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh   23  821-00-0265  Scientist
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh   23  821-00-0265  Scientist
# 7  0x1609   CUS_0xd40    August              NaN   23               Scientist
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj   28  004-07-5839
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj   28  004-07-5839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %%
df.tail(10)
# Out:
#             ID Customer_ID     Month            Name Age          SSN  \
# 99990  0x25fe0  CUS_0x8600      July  Sarah McBridec  28  031-35-0942
# 99991  0x25fe1  CUS_0x8600    August  Sarah McBridec  29  031-35-0942
# 99992  0x25fe6  CUS_0x942c   January           Nicks  24  078-73-5990
# 99993  0x25fe7  CUS_0x942c  February           Nicks  25  078-73-5990
# 99994  0x25fe8  CUS_0x942c     March           Nicks  25  078-73-5990
# 99995  0x25fe9  CUS_0x942c     April           Nicks  25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May           Nicks  25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June           Nicks  25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July           Nicks  25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August           Nicks  25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 99990  Architect      20002.88            1929.906667                 10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  object
#  3   Name                      90015 non-null   object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  object
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9985
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### Name

# %%
customer_id1 = df[df['Name'].isnull()]['Customer_ID'].values

# %%
for id in customer_id1:
    realname = ''
    realname = df.loc[(df['Customer_ID'] == id) & (df['Name'].notna())]['Name'].values[0]
    df.loc[(df['Customer_ID'] == id) & (df['Name'].isna()), ['Name']] = realname

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name  Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh   23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh   23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh   23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh   23  821-00-0265  Scientist
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh   23  821-00-0265  Scientist
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh   23  821-00-0265  Scientist
# 7  0x1609   CUS_0xd40    August    Aaron Maashoh   23               Scientist
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj   28  004-07-5839
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj   28  004-07-5839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %%
df['Name'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Age

# %%
df['Age'] = df['Age'].astype(int)

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name  Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh   23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh   23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh   23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh   23  821-00-0265  Scientist
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh   23  821-00-0265  Scientist
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh   23  821-00-0265  Scientist
# 7  0x1609   CUS_0xd40    August    Aaron Maashoh   23               Scientist
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj   28  004-07-5839
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj   28  004-07-5839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %%
df[df['Name']=='Costas Pitasw'][['ID', 'Customer_ID', 'Month', 'Name', 'Age']]
# Out:
#            ID Customer_ID     Month           Name  Age
# 38248  0xf61e  CUS_0x7e94   January  Costas Pitasw   95
# 38249  0xf61f  CUS_0x7e94  February  Costas Pitasw   32
# 38250  0xf620  CUS_0x7e94     March  Costas Pitasw   32
# 38251  0xf621  CUS_0x7e94     April  Costas Pitasw   32
# 38252  0xf622  CUS_0x7e94       May  Costas Pitasw   32
# 38253  0xf623  CUS_0x7e94      June  Costas Pitasw   32
# 38254  0xf624  CUS_0x7e94      July  Costas Pitasw   32
# 38255  0xf625  CUS_0x7e94    August  Costas Pitasw   32

# %%
df[df['Name']=='Marianna Parragac'][['ID', 'Customer_ID', 'Month', 'Name', 'Age']]
# Out:
#           ID Customer_ID     Month               Name  Age
# 3544  0x2ac6  CUS_0x303a   January  Marianna Parragac   55
# 3545  0x2ac7  CUS_0x303a  February  Marianna Parragac   56
# 3546  0x2ac8  CUS_0x303a     March  Marianna Parragac   56
# 3547  0x2ac9  CUS_0x303a     April  Marianna Parragac   56
# 3548  0x2aca  CUS_0x303a       May  Marianna Parragac   56
# 3549  0x2acb  CUS_0x303a      June  Marianna Parragac   56
# 3550  0x2acc  CUS_0x303a      July  Marianna Parragac   56
# 3551  0x2acd  CUS_0x303a    August  Marianna Parragac   56

# %% [markdown]
# #### After combining with Excel Filter, It seems that values > 56 are false

# %%
df['Age'] = df['Age'].apply(lambda x: np.nan if x > 56 else x)

# %%
#create a dictionary to map Customer_ID keys with Age values
age1  = df.dropna(subset = 'Age').set_index('Customer_ID')['Age'].to_dict()

#fill missing Age values based on Customer_ID 
df['Age'] = df.apply(lambda row: age1.get(row['Customer_ID'],row['SSN']), axis = 1)

# %%
df[df['Name']=='Costas Pitasw'][['ID', 'Customer_ID', 'Month', 'Name', 'Age']]
# Out:
#            ID Customer_ID     Month           Name   Age
# 38248  0xf61e  CUS_0x7e94   January  Costas Pitasw  32.0
# 38249  0xf61f  CUS_0x7e94  February  Costas Pitasw  32.0
# 38250  0xf620  CUS_0x7e94     March  Costas Pitasw  32.0
# 38251  0xf621  CUS_0x7e94     April  Costas Pitasw  32.0
# 38252  0xf622  CUS_0x7e94       May  Costas Pitasw  32.0
# 38253  0xf623  CUS_0x7e94      June  Costas Pitasw  32.0
# 38254  0xf624  CUS_0x7e94      July  Costas Pitasw  32.0
# 38255  0xf625  CUS_0x7e94    August  Costas Pitasw  32.0

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### SSN

# %% [markdown]
# #### fill real values into NaN values

# %%
#replace blanks into NaNs
df['SSN'] = df['SSN'].replace('', np.nan)

# %%
df[(df['Name'].isnull()) | (df['SSN'].isnull())]
# Out:
#             ID Customer_ID    Month              Name   Age  SSN  \
# 7       0x1609   CUS_0xd40   August     Aaron Maashoh  23.0  NaN
# 29      0x162b  CUS_0xb891     June            Jasond  55.0  NaN
# 51      0x164d  CUS_0x284a    April            Nadiaq  34.0  NaN
# 54      0x1650  CUS_0x284a     July            Nadiaq  34.0  NaN
# 98      0x1694  CUS_0x3e45    March   Harriet McLeodd  36.0  NaN
# ...        ...         ...      ...               ...   ...  ...
# 99914  0x25f70  CUS_0x1619    March       Phil Wahbao  54.0  NaN
# 99942  0x25f98  CUS_0xad4f     July  Sabina Zawadzkig  48.0  NaN
# 99946  0x25fa0  CUS_0x51b3    March             Ryana  33.0  NaN
# 99968  0x25fc2   CUS_0xf16  January    Maria Sheahanb  45.0  NaN
# 99988  0x25fde  CUS_0x8600      May    Sarah McBridec  29.0  NaN
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 7          Scientist      19114.12            1824.843333                  3
# ...

# %%
customer_id1 = df[df['SSN']== 'NaN']['Customer_ID'].values
customer_id1
# Out:
# array([], dtype=object)

# %%
#create a dictionary to map Customer_ID keys with SSN values
ssn1  = df.dropna(subset = 'SSN').set_index('Customer_ID')['SSN'].to_dict()

#fill missing SSN values based on Customer_ID 
df['SSN'] = df.apply(lambda row: ssn1.get(row['Customer_ID'],row['SSN']), axis = 1)

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name   Age          SSN  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh  23.0  821-00-0265
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821-00-0265
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  23.0  821-00-0265
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh  23.0  821-00-0265
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh  23.0  821-00-0265
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh  23.0  821-00-0265
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh  23.0  821-00-0265
# 7  0x1609   CUS_0xd40    August    Aaron Maashoh  23.0  821-00-0265
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj  28.0  004-07-5839
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj  28.0  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0  Scientist      19114.12            1824.843333                  3
# 1  Scientist      19114.12                    NaN                  3
# ...

# %%
df['SSN'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Convert data from xxx-yy-zzzz into xxxyyzzzz type and SSN column into int64 type

# %%
df.SSN = df.SSN.apply(lambda x: int(''.join(x.split('-'))) if pd.notna(x) else x).astype(np.int64)

#when SSN column has no NaN values
#df['SSN'] = df['SSN'].apply(lambda x: x.replace('-',''))
#df['SSN'] = df['SSN'].astype('int64')
#df

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name   Age        SSN Occupation  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh  23.0  821000265  Scientist
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821000265  Scientist
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  23.0  821000265  Scientist
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh  23.0  821000265  Scientist
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh  23.0  821000265  Scientist
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh  23.0  821000265  Scientist
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh  23.0  821000265  Scientist
# 7  0x1609   CUS_0xd40    August    Aaron Maashoh  23.0  821000265  Scientist
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj  28.0    4075839
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj  28.0    4075839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %% [markdown]
# ### Occupation

# %%
df[df['Occupation'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []

# %%
#create a dictionary to map Customer_ID keys with Occupation values
occupation1 = df.set_index('Customer_ID')['Occupation'].to_dict()

#fill missing Occupation values based on Customer_ID 
df['Occupation'] = df.apply(lambda row: occupation1.get(row['Customer_ID'], row['Occupation']), axis = 1)

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name   Age        SSN Occupation  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh  23.0  821000265  Scientist
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821000265  Scientist
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  23.0  821000265  Scientist
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh  23.0  821000265  Scientist
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh  23.0  821000265  Scientist
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh  23.0  821000265  Scientist
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh  23.0  821000265  Scientist
# 7  0x1609   CUS_0xd40    August    Aaron Maashoh  23.0  821000265  Scientist
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj  28.0    4075839    Teacher
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj  28.0    4075839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %% [markdown]
# ### Monthly_inhand_salary

# %%
df[df['Monthly_Inhand_Salary'].isnull()]
# Out:
#             ID Customer_ID     Month             Name   Age        SSN  \
# 1       0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821000265
# 2       0x1604   CUS_0xd40     March    Aaron Maashoh  23.0  821000265
# 3       0x1605   CUS_0xd40     April    Aaron Maashoh  23.0  821000265
# 5       0x1607   CUS_0xd40      June    Aaron Maashoh  23.0  821000265
# 11      0x1611  CUS_0x21b1     April  Rick Rothackerj  28.0    4075839
# ...        ...         ...       ...              ...   ...        ...
# 99944  0x25f9e  CUS_0x51b3   January            Ryana  33.0  837859800
# 99955  0x25fad  CUS_0x2084     April            Ryanl  21.0  253727758
# 99963  0x25fb9  CUS_0x372c     April  Lucia Mutikanik  19.0  340857301
# 99975  0x25fc9   CUS_0xf16    August   Maria Sheahanb  45.0  868702218
# 99978  0x25fd0  CUS_0xaf61     March   Chris Wickhamm  50.0  133167738
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
#create a dictionary to map Customer_ID keys with Monthly_Inhand_Salary values
monhtlysalary1 = df.dropna(subset = 'Monthly_Inhand_Salary').set_index('Customer_ID')['Monthly_Inhand_Salary'].to_dict()

#fill missing Monthly_Inhand_Salary values based on Customer_ID 
df['Monthly_Inhand_Salary'] = df.apply(lambda row: monhtlysalary1.get(row['Customer_ID'], row['Monthly_Inhand_Salary']), axis = 1)

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name   Age        SSN Occupation  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh  23.0  821000265  Scientist
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821000265  Scientist
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  23.0  821000265  Scientist
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh  23.0  821000265  Scientist
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh  23.0  821000265  Scientist
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh  23.0  821000265  Scientist
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh  23.0  821000265  Scientist
# 7  0x1609   CUS_0xd40    August    Aaron Maashoh  23.0  821000265  Scientist
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj  28.0    4075839    Teacher
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj  28.0    4075839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %% [markdown]
# ### Num_bank_accounts

# %%
df['Num_Bank_Accounts'] = df['Num_Bank_Accounts'].astype(int)

# %%
df[df['Name']=='Davidc'][['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'Num_Bank_Accounts']]
# Out:
#             ID Customer_ID     Month    Name   Age  Num_Bank_Accounts
# 5216    0x3492  CUS_0x61b7   January  Davidc  14.0                322
# 5217    0x3493  CUS_0x61b7  February  Davidc  14.0                 10
# 5218    0x3494  CUS_0x61b7     March  Davidc  14.0                 10
# 5219    0x3495  CUS_0x61b7     April  Davidc  14.0                628
# 5220    0x3496  CUS_0x61b7       May  Davidc  14.0                 10
# 5221    0x3497  CUS_0x61b7      June  Davidc  14.0                 10
# 5222    0x3498  CUS_0x61b7      July  Davidc  14.0                 10
# 5223    0x3499  CUS_0x61b7    August  Davidc  14.0                 10
# 30960   0xcb6a  CUS_0x219b   January  Davidc  41.0                  7
# 30961   0xcb6b  CUS_0x219b  February  Davidc  41.0                  7
# 30962   0xcb6c  CUS_0x219b     March  Davidc  41.0                  7
# 30963   0xcb6d  CUS_0x219b     April  Davidc  41.0                  7
# ...

# %%
df[df['Name']=='Douwem'][['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'Num_Bank_Accounts']]
# Out:
#             ID Customer_ID     Month    Name   Age  Num_Bank_Accounts
# 73216  0x1c302  CUS_0x39c5   January  Douwem  44.0                  6
# 73217  0x1c303  CUS_0x39c5  February  Douwem  44.0                  6
# 73218  0x1c304  CUS_0x39c5     March  Douwem  44.0                  6
# 73219  0x1c305  CUS_0x39c5     April  Douwem  44.0                 18
# 73220  0x1c306  CUS_0x39c5       May  Douwem  44.0                  6
# 73221  0x1c307  CUS_0x39c5      June  Douwem  44.0                  6
# 73222  0x1c308  CUS_0x39c5      July  Douwem  44.0                  6
# 73223  0x1c309  CUS_0x39c5    August  Douwem  44.0                  6

# %% [markdown]
# #### After combining with Excel Filter, It seems that values > 11 are false

# %%
df['Num_Bank_Accounts'] = df['Num_Bank_Accounts'].apply(lambda x: np.nan if x > 11 else x)

# %%
#create a dictionary to map Customer_ID keys with Num_Bank_Accounts values
num_account  = df.dropna(subset = 'Num_Bank_Accounts').set_index('Customer_ID')['Num_Bank_Accounts'].to_dict()

#fill missing Num_Bank_Accounts values based on Customer_ID 
df['Num_Bank_Accounts'] = df.apply(lambda row: num_account.get(row['Customer_ID'],row['Num_Bank_Accounts']), axis = 1)

# %%
df[df['Name']=='Douwem'][['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'Num_Bank_Accounts']]
# Out:
#             ID Customer_ID     Month    Name   Age  Num_Bank_Accounts
# 73216  0x1c302  CUS_0x39c5   January  Douwem  44.0                6.0
# 73217  0x1c303  CUS_0x39c5  February  Douwem  44.0                6.0
# 73218  0x1c304  CUS_0x39c5     March  Douwem  44.0                6.0
# 73219  0x1c305  CUS_0x39c5     April  Douwem  44.0                6.0
# 73220  0x1c306  CUS_0x39c5       May  Douwem  44.0                6.0
# 73221  0x1c307  CUS_0x39c5      June  Douwem  44.0                6.0
# 73222  0x1c308  CUS_0x39c5      July  Douwem  44.0                6.0
# 73223  0x1c309  CUS_0x39c5    August  Douwem  44.0                6.0

# %% [markdown]
# ### Num_Credit_Card

# %%
df['Num_Credit_Card'] = df['Num_Credit_Card'].astype(int)

# %%
df[df['Name']=='Jan Schwartze'][['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'Num_Credit_Card']]
# Out:
#           ID Customer_ID     Month           Name   Age  Num_Credit_Card
# 1000  0x1bde  CUS_0x3187   January  Jan Schwartze  40.0               10
# 1001  0x1bdf  CUS_0x3187  February  Jan Schwartze  40.0               10
# 1002  0x1be0  CUS_0x3187     March  Jan Schwartze  40.0               11
# 1003  0x1be1  CUS_0x3187     April  Jan Schwartze  40.0               11
# 1004  0x1be2  CUS_0x3187       May  Jan Schwartze  40.0               11
# 1005  0x1be3  CUS_0x3187      June  Jan Schwartze  40.0               11
# 1006  0x1be4  CUS_0x3187      July  Jan Schwartze  40.0               11
# 1007  0x1be5  CUS_0x3187    August  Jan Schwartze  40.0               11

# %%
df[df['Name']=='Michelle Martino'][['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'Num_Credit_Card']]
# Out:
#             ID Customer_ID     Month              Name   Age  Num_Credit_Card
# 50672  0x13eea  CUS_0x95e7   January  Michelle Martino  22.0                9
# 50673  0x13eeb  CUS_0x95e7  February  Michelle Martino  22.0                9
# 50674  0x13eec  CUS_0x95e7     March  Michelle Martino  22.0               15
# 50675  0x13eed  CUS_0x95e7     April  Michelle Martino  22.0                9
# 50676  0x13eee  CUS_0x95e7       May  Michelle Martino  22.0                9
# 50677  0x13eef  CUS_0x95e7      June  Michelle Martino  22.0                9
# 50678  0x13ef0  CUS_0x95e7      July  Michelle Martino  22.0                9
# 50679  0x13ef1  CUS_0x95e7    August  Michelle Martino  22.0                9

# %% [markdown]
# #### After combining with Excel Filter, It seems that values > 11 are false

# %%
df['Num_Credit_Card'] = df['Num_Credit_Card'].apply(lambda x: np.nan if x > 11 else x)

# %%
#create a dictionary to map Customer_ID keys with Num_Credit_Card values
num_card  = df.dropna(subset = 'Num_Credit_Card').set_index('Customer_ID')['Num_Credit_Card'].to_dict()

#fill missing Num_Credit_Card values based on Customer_ID 
df['Num_Credit_Card'] = df.apply(lambda row: num_card.get(row['Customer_ID'],row['Num_Credit_Card']), axis = 1)

# %%
df[df['Name']=='Michelle Martino'][['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'Num_Credit_Card']]
# Out:
#             ID Customer_ID     Month              Name   Age  Num_Credit_Card
# 50672  0x13eea  CUS_0x95e7   January  Michelle Martino  22.0              9.0
# 50673  0x13eeb  CUS_0x95e7  February  Michelle Martino  22.0              9.0
# 50674  0x13eec  CUS_0x95e7     March  Michelle Martino  22.0              9.0
# 50675  0x13eed  CUS_0x95e7     April  Michelle Martino  22.0              9.0
# 50676  0x13eee  CUS_0x95e7       May  Michelle Martino  22.0              9.0
# 50677  0x13eef  CUS_0x95e7      June  Michelle Martino  22.0              9.0
# 50678  0x13ef0  CUS_0x95e7      July  Michelle Martino  22.0              9.0
# 50679  0x13ef1  CUS_0x95e7    August  Michelle Martino  22.0              9.0

# %% [markdown]
# ### Interest_Rate

# %%
df['Interest_Rate'] = df['Interest_Rate'].astype(int)

# %%
df[df['Name']=='Clarkew'][['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'Interest_Rate']]
# Out:
#          ID Customer_ID     Month     Name   Age  Interest_Rate
# 936  0x1b7e  CUS_0x5e17   January  Clarkew  33.0             34
# 937  0x1b7f  CUS_0x5e17  February  Clarkew  33.0             34
# 938  0x1b80  CUS_0x5e17     March  Clarkew  33.0             34
# 939  0x1b81  CUS_0x5e17     April  Clarkew  33.0             34
# 940  0x1b82  CUS_0x5e17       May  Clarkew  33.0             34
# 941  0x1b83  CUS_0x5e17      June  Clarkew  33.0             34
# 942  0x1b84  CUS_0x5e17      July  Clarkew  33.0             34
# 943  0x1b85  CUS_0x5e17    August  Clarkew  33.0             34

# %%
df[df['Name']=='Silvia Aloisiq'][['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'Interest_Rate']]
# Out:
#             ID Customer_ID     Month            Name   Age  Interest_Rate
# 536     0x1926  CUS_0xa156   January  Silvia Aloisiq  42.0             15
# 537     0x1927  CUS_0xa156  February  Silvia Aloisiq  42.0             15
# 538     0x1928  CUS_0xa156     March  Silvia Aloisiq  42.0             15
# 539     0x1929  CUS_0xa156     April  Silvia Aloisiq  42.0             15
# 540     0x192a  CUS_0xa156       May  Silvia Aloisiq  42.0             15
# 541     0x192b  CUS_0xa156      June  Silvia Aloisiq  42.0             15
# 542     0x192c  CUS_0xa156      July  Silvia Aloisiq  42.0             15
# 543     0x192d  CUS_0xa156    August  Silvia Aloisiq  42.0             15
# 35440   0xe5aa  CUS_0x5f90   January  Silvia Aloisiq  15.0             14
# 35441   0xe5ab  CUS_0x5f90  February  Silvia Aloisiq  15.0             14
# 35442   0xe5ac  CUS_0x5f90     March  Silvia Aloisiq  15.0             59
# 35443   0xe5ad  CUS_0x5f90     April  Silvia Aloisiq  15.0             14
# ...

# %% [markdown]
# #### After combining with Excel Filter, It seems that values > 34 are false

# %%
df['Interest_Rate'] = df['Interest_Rate'].apply(lambda x: np.nan if x > 34 else x)

# %%
#create a dictionary to map Customer_ID keys with Interest_Rate values
interest_rate  = df.dropna(subset = 'Interest_Rate').set_index('Customer_ID')['Interest_Rate'].to_dict()

#fill missing Interest_Rate values based on Customer_ID 
df['Interest_Rate'] = df.apply(lambda row: interest_rate.get(row['Customer_ID'],row['Interest_Rate']), axis = 1)

# %%
df[df['Name']=='Silvia Aloisiq'][['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'Interest_Rate']]
# Out:
#             ID Customer_ID     Month            Name   Age  Interest_Rate
# 536     0x1926  CUS_0xa156   January  Silvia Aloisiq  42.0           15.0
# 537     0x1927  CUS_0xa156  February  Silvia Aloisiq  42.0           15.0
# 538     0x1928  CUS_0xa156     March  Silvia Aloisiq  42.0           15.0
# 539     0x1929  CUS_0xa156     April  Silvia Aloisiq  42.0           15.0
# 540     0x192a  CUS_0xa156       May  Silvia Aloisiq  42.0           15.0
# 541     0x192b  CUS_0xa156      June  Silvia Aloisiq  42.0           15.0
# 542     0x192c  CUS_0xa156      July  Silvia Aloisiq  42.0           15.0
# 543     0x192d  CUS_0xa156    August  Silvia Aloisiq  42.0           15.0
# 35440   0xe5aa  CUS_0x5f90   January  Silvia Aloisiq  15.0           14.0
# 35441   0xe5ab  CUS_0x5f90  February  Silvia Aloisiq  15.0           14.0
# 35442   0xe5ac  CUS_0x5f90     March  Silvia Aloisiq  15.0           14.0
# 35443   0xe5ad  CUS_0x5f90     April  Silvia Aloisiq  15.0           14.0
# ...

# %% [markdown]
# ### Num_of_Loan

# %%
print(df.columns)
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
df[df['Name'] == 'Langep'][['Customer_ID','Name','Num_of_Loan', 'Type_of_Loan']]
# Out:
#       Customer_ID    Name Num_of_Loan  \
# 16     CUS_0x2dbc  Langep           3
# 17     CUS_0x2dbc  Langep           3
# 18     CUS_0x2dbc  Langep           3
# 19     CUS_0x2dbc  Langep           3
# 20     CUS_0x2dbc  Langep           3
# 21     CUS_0x2dbc  Langep         967
# 22     CUS_0x2dbc  Langep           3
# 23     CUS_0x2dbc  Langep           3
# 11872  CUS_0xaf95  Langep           6
# 11873  CUS_0xaf95  Langep           6
# 11874  CUS_0xaf95  Langep           6
# 11875  CUS_0xaf95  Langep           6
# 11876  CUS_0xaf95  Langep           6
# 11877  CUS_0xaf95  Langep           6
# 11878  CUS_0xaf95  Langep           6
# 11879  CUS_0xaf95  Langep         100
# 44856  CUS_0x109d  Langep           6
# 44857  CUS_0x109d  Langep           6
# 44858  CUS_0x109d  Langep           6
# 44859  CUS_0x109d  Langep           6
# 44860  CUS_0x109d  Langep           6
# 44861  CUS_0x109d  Langep           6
# 44862  CUS_0x109d  Langep           6
# ...

# %% [markdown]
# #### It seems like there are a lot of unrealistic values,  and after using Excel filter, it seems that values > 9 are false

# %%
df[df['Num_of_Loan'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []

# %%
df['Num_of_Loan'] = df['Num_of_Loan'].astype(int)

# %%
def replace_Num_of_Loan(group):
    min_Num_of_Loan = group['Num_of_Loan'].min()
    max_Num_of_Loan = group['Num_of_Loan'].max()
    group['Num_of_Loan'] = group['Num_of_Loan'].apply(lambda x: min_Num_of_Loan if x < 1 or x > 10 else x)
    return group

# Apply the function to the DataFrame using groupby and transform
df = df.groupby('Customer_ID').apply(replace_Num_of_Loan).reset_index(drop=True)
# Out:
# C:\Users\t\AppData\Local\Temp\ipykernel_8212\2860682734.py:8: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df = df.groupby('Customer_ID').apply(replace_Num_of_Loan).reset_index(drop=True)

# %%
df[df['Name'] == 'Langep'][['Customer_ID','Name','Num_of_Loan', 'Type_of_Loan']]
# Out:
#       Customer_ID    Name  Num_of_Loan  \
# 16     CUS_0x2dbc  Langep            3
# 17     CUS_0x2dbc  Langep            3
# 18     CUS_0x2dbc  Langep            3
# 19     CUS_0x2dbc  Langep            3
# 20     CUS_0x2dbc  Langep            3
# 21     CUS_0x2dbc  Langep            3
# 22     CUS_0x2dbc  Langep            3
# 23     CUS_0x2dbc  Langep            3
# 11872  CUS_0xaf95  Langep            6
# 11873  CUS_0xaf95  Langep            6
# 11874  CUS_0xaf95  Langep            6
# 11875  CUS_0xaf95  Langep            6
# 11876  CUS_0xaf95  Langep            6
# 11877  CUS_0xaf95  Langep            6
# 11878  CUS_0xaf95  Langep            6
# 11879  CUS_0xaf95  Langep            6
# 44856  CUS_0x109d  Langep            6
# 44857  CUS_0x109d  Langep            6
# 44858  CUS_0x109d  Langep            6
# 44859  CUS_0x109d  Langep            6
# 44860  CUS_0x109d  Langep            6
# 44861  CUS_0x109d  Langep            6
# 44862  CUS_0x109d  Langep            6
# ...

# %%
# replace blanks into 0 
df['Num_of_Loan'] = df['Num_of_Loan'].replace('','0', regex = True)

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name   Age        SSN Occupation  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh  23.0  821000265  Scientist
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821000265  Scientist
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  23.0  821000265  Scientist
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh  23.0  821000265  Scientist
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh  23.0  821000265  Scientist
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh  23.0  821000265  Scientist
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh  23.0  821000265  Scientist
# 7  0x1609   CUS_0xd40    August    Aaron Maashoh  23.0  821000265  Scientist
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj  28.0    4075839    Teacher
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj  28.0    4075839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %% [markdown]
# ### Type_of_Loan

# %%
df['Type_of_Loan'].unique()
# Out:
# array(['Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan',
#        'Credit-Builder Loan', 'Auto Loan, Auto Loan, and Not Specified',
#        ..., 'Home Equity Loan, Auto Loan, Auto Loan, and Auto Loan',
#        'Payday Loan, Student Loan, Mortgage Loan, and Not Specified',
#        'Personal Loan, Auto Loan, Mortgage Loan, Student Loan, and Student Loan'],
#       dtype=object)

# %%
df[df['Type_of_Loan'].isnull()][['Customer_ID','Name','Num_of_Loan', 'Type_of_Loan']]
# Out:
#       Customer_ID              Name  Num_of_Loan Type_of_Loan
# 32     CUS_0x1cdb            Deepaa            0          NaN
# 33     CUS_0x1cdb            Deepaa            0          NaN
# 34     CUS_0x1cdb            Deepaa            0          NaN
# 35     CUS_0x1cdb            Deepaa            0          NaN
# 36     CUS_0x1cdb            Deepaa            0          NaN
# ...           ...               ...          ...          ...
# 99939  CUS_0xad4f  Sabina Zawadzkig            0          NaN
# 99940  CUS_0xad4f  Sabina Zawadzkig            0          NaN
# 99941  CUS_0xad4f  Sabina Zawadzkig            0          NaN
# 99942  CUS_0xad4f  Sabina Zawadzkig            0          NaN
# 99943  CUS_0xad4f  Sabina Zawadzkig            0          NaN
#
# [11408 rows x 4 columns]

# %%
df[df['Name'] == 'Deepaa'][['Customer_ID','Name','Num_of_Loan', 'Type_of_Loan']]
# Out:
#       Customer_ID    Name  Num_of_Loan  \
# 32     CUS_0x1cdb  Deepaa            0
# 33     CUS_0x1cdb  Deepaa            0
# 34     CUS_0x1cdb  Deepaa            0
# 35     CUS_0x1cdb  Deepaa            0
# 36     CUS_0x1cdb  Deepaa            0
# 37     CUS_0x1cdb  Deepaa            0
# 38     CUS_0x1cdb  Deepaa            0
# 39     CUS_0x1cdb  Deepaa            0
# 7376   CUS_0x111c  Deepaa            8
# 7377   CUS_0x111c  Deepaa            8
# 7378   CUS_0x111c  Deepaa            8
# 7379   CUS_0x111c  Deepaa            8
# 7380   CUS_0x111c  Deepaa            8
# 7381   CUS_0x111c  Deepaa            8
# 7382   CUS_0x111c  Deepaa            8
# 7383   CUS_0x111c  Deepaa            8
# 38632  CUS_0x1e06  Deepaa            3
# 38633  CUS_0x1e06  Deepaa            3
# 38634  CUS_0x1e06  Deepaa            3
# 38635  CUS_0x1e06  Deepaa            3
# 38636  CUS_0x1e06  Deepaa            3
# 38637  CUS_0x1e06  Deepaa            3
# 38638  CUS_0x1e06  Deepaa            3
# ...

# %%
df[df['Occupation'] == 'Musician'][['Customer_ID','Name','Num_of_Loan', 'Type_of_Loan']]
# Out:
#       Customer_ID             Name  Num_of_Loan  \
# 144    CUS_0x3553  Laurence Frosty            0
# 145    CUS_0x3553  Laurence Frosty            0
# 146    CUS_0x3553  Laurence Frosty            0
# 147    CUS_0x3553  Laurence Frosty            0
# 148    CUS_0x3553  Laurence Frosty            0
# ...           ...              ...          ...
# 99867  CUS_0x1d18     Dominic Lauv            2
# 99868  CUS_0x1d18     Dominic Lauv            2
# 99869  CUS_0x1d18     Dominic Lauv            2
# 99870  CUS_0x1d18     Dominic Lauv            2
# 99871  CUS_0x1d18     Dominic Lauv            2
#
#                            Type_of_Loan
# 144                                 NaN
# 145                                 NaN
# 146                                 NaN
# 147                                 NaN
# 148                                 NaN
# ...                                 ...
# 99867  Mortgage Loan, and Not Specified
# 99868  Mortgage Loan, and Not Specified
# ...

# %%
# replace NaNs and blanks into 'Not Specified' values
df['Type_of_Loan'].fillna('Not Specified', inplace = True)
df['Type_of_Loan'].replace('', 'Not Specified')
# Out:
# 0        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 1        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 2        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 3        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 4        Auto Loan, Credit-Builder Loan, Personal Loan,...
#                                ...
# 99995                          Auto Loan, and Student Loan
# 99996                          Auto Loan, and Student Loan
# 99997                          Auto Loan, and Student Loan
# 99998                          Auto Loan, and Student Loan
# 99999                          Auto Loan, and Student Loan
# Name: Type_of_Loan, Length: 100000, dtype: object

# %%
df['Type_of_Loan'].isnull().sum()
# Out:
# 0

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name   Age        SSN Occupation  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh  23.0  821000265  Scientist
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821000265  Scientist
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  23.0  821000265  Scientist
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh  23.0  821000265  Scientist
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh  23.0  821000265  Scientist
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh  23.0  821000265  Scientist
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh  23.0  821000265  Scientist
# 7  0x1609   CUS_0xd40    August    Aaron Maashoh  23.0  821000265  Scientist
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj  28.0    4075839    Teacher
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj  28.0    4075839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %% [markdown]
# ### Changed_Credit_Limit

# %%
df.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                         float64
# SSN                           int64
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts           float64
# Num_Credit_Card             float64
# Interest_Rate               float64
# Num_of_Loan                   int64
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# ...

# %%
#replace blanks into NaN values
df['Changed_Credit_Limit'] = df['Changed_Credit_Limit'].replace('', float('nan'))

# %%
#change Changed_Credit_Limit into float type
df['Changed_Credit_Limit'] = df['Changed_Credit_Limit'].astype(float)

# %%
df[df['Changed_Credit_Limit'].isnull()]
# Out:
#             ID Customer_ID     Month            Name   Age        SSN  \
# 2       0x1604   CUS_0xd40     March   Aaron Maashoh  23.0  821000265
# 65      0x1663  CUS_0x4157  February    Charlie Zhur  24.0   70191622
# 66      0x1664  CUS_0x4157     March    Charlie Zhur  24.0   70191622
# 109     0x16a3  CUS_0x6c66      June   Sinead Carews  39.0  328336328
# 110     0x16a4  CUS_0x6c66      July   Sinead Carews  39.0  328336328
# ...        ...         ...       ...             ...   ...        ...
# 99548  0x25d4a  CUS_0x2637       May    Diane Bartzj  28.0  272331370
# 99618  0x25db4  CUS_0xae66     March            Jino  31.0  721454479
# 99800  0x25ec6  CUS_0x1232   January         Lawderr  17.0  441261297
# 99892  0x25f4e  CUS_0x89aa       May           Kwokw  39.0   18637005
# 99931  0x25f89  CUS_0xb11c     April  Yinka Adegokej  38.0  546944789
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df[df['Name']=='Aaron Maashoh'][['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
       'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
       'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
       'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit']]
# Out:
#        ID Customer_ID     Month           Name   Age        SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh  23.0  821000265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh  23.0  821000265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  23.0  821000265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh  23.0  821000265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh  23.0  821000265  Scientist
# 5  0x1607   CUS_0xd40      June  Aaron Maashoh  23.0  821000265  Scientist
# 6  0x1608   CUS_0xd40      July  Aaron Maashoh  23.0  821000265  Scientist
# 7  0x1609   CUS_0xd40    August  Aaron Maashoh  23.0  821000265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0      19114.12            1824.843333                3.0              4.0
# 1      19114.12            1824.843333                3.0              4.0
# ...

# %% [markdown]
# #### For each customer, values in Changed_Credit_Limit column are not exactly the same, so i will use interpolation method to calculate missing values in the data sequence

# %%
df['Changed_Credit_Limit'] = df.groupby('Customer_ID')['Changed_Credit_Limit'].transform(lambda x: x.interpolate(method='index', limit_direction='both'))

# %%
df[df['Name'] == 'Charlie Zhur'][['Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
       'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
       'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
       'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',]]
# Out:
#    Customer_ID     Month          Name   Age       SSN Occupation  \
# 64  CUS_0x4157   January  Charlie Zhur  24.0  70191622     Doctor
# 65  CUS_0x4157  February  Charlie Zhur  24.0  70191622     Doctor
# 66  CUS_0x4157     March  Charlie Zhur  24.0  70191622     Doctor
# 67  CUS_0x4157     April  Charlie Zhur  24.0  70191622     Doctor
# 68  CUS_0x4157       May  Charlie Zhur  24.0  70191622     Doctor
# 69  CUS_0x4157      June  Charlie Zhur  24.0  70191622     Doctor
# 70  CUS_0x4157      July  Charlie Zhur  24.0  70191622     Doctor
# 71  CUS_0x4157    August  Charlie Zhur  24.0  70191622     Doctor
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 64     114838.41              9843.8675                2.0              5.0
# 65     114838.41              9843.8675                2.0              5.0
# 66     114838.41              9843.8675                2.0              5.0
# ...

# %%
df['Changed_Credit_Limit'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Num_of_delayed_payment

# %%
df.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                         float64
# SSN                           int64
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts           float64
# Num_Credit_Card             float64
# Interest_Rate               float64
# Num_of_Loan                   int64
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit        float64
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# ...

# %%
#replace NaNs values into NaN values type of float
df['Num_of_Delayed_Payment'] = df['Num_of_Delayed_Payment'].replace('nan', float('nan'))

# %%
#change Changed_Credit_Limit into float type
df['Num_of_Delayed_Payment'] = df['Num_of_Delayed_Payment'].astype(float)

# %%
df[df['Num_of_Delayed_Payment'].isnull()]
# Out:
#             ID Customer_ID     Month            Name   Age        SSN  \
# 1       0x1603   CUS_0xd40  February   Aaron Maashoh  23.0  821000265
# 4       0x1606   CUS_0xd40       May   Aaron Maashoh  23.0  821000265
# 30      0x162c  CUS_0xb891      July          Jasond  55.0   72316145
# 32      0x1632  CUS_0x1cdb   January          Deepaa  21.0  615067821
# 33      0x1633  CUS_0x1cdb  February          Deepaa  21.0  615067821
# ...        ...         ...       ...             ...   ...        ...
# 99973  0x25fc7   CUS_0xf16      June  Maria Sheahanb  45.0  868702218
# 99974  0x25fc8   CUS_0xf16      July  Maria Sheahanb  45.0  868702218
# 99992  0x25fe6  CUS_0x942c   January           Nicks  25.0   78735990
# 99993  0x25fe7  CUS_0x942c  February           Nicks  25.0   78735990
# 99998  0x25fec  CUS_0x942c      July           Nicks  25.0   78735990
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
customer_id1 = df[(df['Num_of_Delayed_Payment'].isna())]['Customer_ID'].values

# groupby Customer_ID and interpolate Num_of_Delayed_Payment values 
df['Num_of_Delayed_Payment'] = df.groupby('Customer_ID')['Num_of_Delayed_Payment'].transform(
    lambda x: x.interpolate(method='index', limit_direction='both') if x.count() > 1 else x)

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name   Age        SSN Occupation  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh  23.0  821000265  Scientist
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821000265  Scientist
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  23.0  821000265  Scientist
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh  23.0  821000265  Scientist
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh  23.0  821000265  Scientist
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh  23.0  821000265  Scientist
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh  23.0  821000265  Scientist
# 7  0x1609   CUS_0xd40    August    Aaron Maashoh  23.0  821000265  Scientist
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj  28.0    4075839    Teacher
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj  28.0    4075839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %%
df.isnull().sum()
# Out:
# ID                             0
# Customer_ID                    0
# Month                          0
# Name                           0
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary          0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                   0
# Delay_from_due_date            0
# Num_of_Delayed_Payment         0
# Changed_Credit_Limit           0
# Num_Credit_Inquiries        1965
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          9030
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     4479
# Payment_Behaviour              0
# Monthly_Balance             1200
# Credit_Score                   0
# dtype: int64

# %% [markdown]
# ### Num_credit_inquiries

# %%
df[df['Num_Credit_Inquiries'].isnull()]
# Out:
#             ID Customer_ID     Month             Name   Age        SSN  \
# 18      0x161c  CUS_0x2dbc     March           Langep  34.0  486853974
# 47      0x1645  CUS_0x95ee    August               Np  31.0  612708987
# 113     0x16ab   CUS_0xff4  February        Poornimaf  37.0  655057666
# 115     0x16ad   CUS_0xff4     April        Poornimaf  37.0  655057666
# 187     0x1719  CUS_0x5b48     April         McBrideq  32.0  706950150
# ...        ...         ...       ...              ...   ...        ...
# 99768  0x25e96  CUS_0xc345   January      Jeb Blountf  24.0  176400757
# 99852  0x25f12  CUS_0x3048       May  Rick Rothackeru  40.0  375646913
# 99874  0x25f34  CUS_0x3855     March            Xolai  27.0  963557106
# 99900  0x25f5a  CUS_0x4986       May  Charles Abbotta  34.0  971618388
# 99901  0x25f5b  CUS_0x4986      June  Charles Abbotta  34.0  971618388
#
#          Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df[df['Num_Credit_Inquiries'] > 16]
# Out:
#             ID Customer_ID     Month         Name   Age        SSN  \
# 173     0x1703  CUS_0xa16e      June   Lee Chyenz  42.0  905507912
# 193     0x1723  CUS_0xa5f9  February        Rickt  34.0  189095267
# 194     0x1724  CUS_0xa5f9     March        Rickt  34.0  189095267
# 195     0x1725  CUS_0xa5f9     April        Rickt  34.0  189095267
# 196     0x1726  CUS_0xa5f9       May        Rickt  34.0  189095267
# ...        ...         ...       ...          ...   ...        ...
# 99743  0x25e6d  CUS_0x9674    August     Damounit  23.0  949103104
# 99769  0x25e97  CUS_0xc345  February  Jeb Blountf  24.0  176400757
# 99789  0x25eb3  CUS_0x62f5      June      Alexein  54.0  272402510
# 99800  0x25ec6  CUS_0x1232   January      Lawderr  17.0  441261297
# 99872  0x25f32  CUS_0x3855   January        Xolai  27.0  963557106
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 173    Media_Manager     10183.015            1074.584583                7.0
# ...

# %%
customer_id1 = df[(df['Num_Credit_Inquiries'].isna())]['Customer_ID'].values

# groupby Customer_ID and interpolate Num_Credit_Inquiries values 
df['Num_Credit_Inquiries'] = df.groupby('Customer_ID')['Num_Credit_Inquiries'].transform(
    lambda x: x.interpolate(method='index', limit_direction='both') if x.count() > 1 else x)

# %%
df['Num_Credit_Inquiries'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### It seems that interpolation method can't calculate all, so i will use for loop to fill the remaining missing values

# %%
customer_id2 = df[(df['Num_Credit_Inquiries'] > 16) ]['Customer_ID'].values

for x in customer_id2:

    mode_values = df[df['Customer_ID'] == x]['Num_Credit_Inquiries'].mode()[0]

    df.loc[(df['Customer_ID'] == x) & ((df['Num_Credit_Inquiries'] > 16) ), ['Num_Credit_Inquiries']] = mode_values

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name   Age        SSN Occupation  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh  23.0  821000265  Scientist
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821000265  Scientist
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  23.0  821000265  Scientist
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh  23.0  821000265  Scientist
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh  23.0  821000265  Scientist
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh  23.0  821000265  Scientist
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh  23.0  821000265  Scientist
# 7  0x1609   CUS_0xd40    August    Aaron Maashoh  23.0  821000265  Scientist
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj  28.0    4075839    Teacher
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj  28.0    4075839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %% [markdown]
# ### Credit_mix

# %%
df[df['Credit_Mix'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []

# %%
#create a dictionary to map Customer_ID keys with Credit_Mix values
credit_mix1  = df.set_index('Customer_ID')['Credit_Mix'].to_dict()

#fill missing Credit_Mix values based on Customer_ID 
df['Credit_Mix'] = df.apply(lambda row: credit_mix1.get(row['Customer_ID'],row['Credit_Mix']), axis = 1)

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name   Age        SSN Occupation  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh  23.0  821000265  Scientist
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821000265  Scientist
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  23.0  821000265  Scientist
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh  23.0  821000265  Scientist
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh  23.0  821000265  Scientist
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh  23.0  821000265  Scientist
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh  23.0  821000265  Scientist
# 7  0x1609   CUS_0xd40    August    Aaron Maashoh  23.0  821000265  Scientist
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj  28.0    4075839    Teacher
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj  28.0    4075839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %% [markdown]
# ### Credit_history_age

# %%
df[df['Credit_History_Age'].isnull()]
# Out:
#             ID Customer_ID     Month             Name   Age        SSN  \
# 1       0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821000265
# 7       0x1609   CUS_0xd40    August    Aaron Maashoh  23.0  821000265
# 19      0x161d  CUS_0x2dbc     April           Langep  34.0  486853974
# 40      0x163e  CUS_0x95ee   January               Np  31.0  612708987
# 42      0x1640  CUS_0x95ee     March               Np  31.0  612708987
# ...        ...         ...       ...              ...   ...        ...
# 99944  0x25f9e  CUS_0x51b3   January            Ryana  33.0  837859800
# 99963  0x25fb9  CUS_0x372c     April  Lucia Mutikanik  19.0  340857301
# 99968  0x25fc2   CUS_0xf16   January   Maria Sheahanb  45.0  868702218
# 99975  0x25fc9   CUS_0xf16    August   Maria Sheahanb  45.0  868702218
# 99990  0x25fe0  CUS_0x8600      July   Sarah McBridec  29.0   31350942
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df[df['Credit_History_Age'] == '0 Years and 0 Months']
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []

# %%
df[df['Credit_History_Age'] == '0 Years and 1 Months']
# Out:
#           ID Customer_ID    Month               Name   Age        SSN  \
# 2088  0x223e  CUS_0xa672  January  Glenn Somervilleo  32.0  874588010
# 2304  0x2382  CUS_0xadb7  January             Emilym  28.0  332221188
#
#         Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 2088  Entrepreneur      51113.85            4356.487500                7.0
# 2304     Architect      33314.96            2955.246667               10.0
#
#       Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 2088              9.0           30.0            9
# 2304              5.0           18.0            7
#
#                                            Type_of_Loan  Delay_from_due_date  \
# 2088  Auto Loan, Credit-Builder Loan, Home Equity Lo...                   33
# 2304  Mortgage Loan, Student Loan, Auto Loan, Studen...                   33
#
#       Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# ...

# %%
df[df['Name'] == 'Emilym']
# Out:
#           ID Customer_ID     Month    Name   Age        SSN Occupation  \
# 2304  0x2382  CUS_0xadb7   January  Emilym  28.0  332221188  Architect
# 2305  0x2383  CUS_0xadb7  February  Emilym  28.0  332221188  Architect
# 2306  0x2384  CUS_0xadb7     March  Emilym  28.0  332221188  Architect
# 2307  0x2385  CUS_0xadb7     April  Emilym  28.0  332221188  Architect
# 2308  0x2386  CUS_0xadb7       May  Emilym  28.0  332221188  Architect
# 2309  0x2387  CUS_0xadb7      June  Emilym  28.0  332221188  Architect
# 2310  0x2388  CUS_0xadb7      July  Emilym  28.0  332221188  Architect
# 2311  0x2389  CUS_0xadb7    August  Emilym  28.0  332221188  Architect
#
#      Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 2304      33314.96            2955.246667               10.0              5.0
# 2305      33314.96            2955.246667               10.0              5.0
# 2306      33314.96            2955.246667               10.0              5.0
# ...

# %% [markdown]
# #### This column has some values of the form '0 years and x months', so i would be better to convert it into only months

# %%
df.copy()
# Out:
#             ID Customer_ID     Month           Name   Age        SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh  23.0  821000265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh  23.0  821000265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  23.0  821000265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh  23.0  821000265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh  23.0  821000265
# ...        ...         ...       ...            ...   ...        ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks  25.0   78735990
# 99996  0x25fea  CUS_0x942c       May          Nicks  25.0   78735990
# 99997  0x25feb  CUS_0x942c      June          Nicks  25.0   78735990
# 99998  0x25fec  CUS_0x942c      July          Nicks  25.0   78735990
# 99999  0x25fed  CUS_0x942c    August          Nicks  25.0   78735990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df1 = df.copy()

# %%
def month_converter(x):
    if pd.notnull(x):
        year = int(x.split(' ')[0])
        month = int(x.split(' ')[3])
        return (year*12) + month
    else:
        return x

# %%
df['Credit_History_Age'] = df['Credit_History_Age'].apply(lambda x: month_converter(x)).astype(np.float64)

# %%
customer_id1 = df[(df['Credit_History_Age'].isna())]['Customer_ID'].values

# groupby Customer_ID and interpolate Credit_History_Age values 
df['Credit_History_Age'] = df.groupby('Customer_ID')['Credit_History_Age'].transform(
    lambda x: x.interpolate(method='index', limit_direction='both') if x.count() > 1 else x)

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name   Age        SSN Occupation  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh  23.0  821000265  Scientist
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821000265  Scientist
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  23.0  821000265  Scientist
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh  23.0  821000265  Scientist
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh  23.0  821000265  Scientist
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh  23.0  821000265  Scientist
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh  23.0  821000265  Scientist
# 7  0x1609   CUS_0xd40    August    Aaron Maashoh  23.0  821000265  Scientist
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj  28.0    4075839    Teacher
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj  28.0    4075839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %%
df['Credit_History_Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Amount_invested_monthly

# %%
df.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                         float64
# SSN                           int64
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts           float64
# Num_Credit_Card             float64
# Interest_Rate               float64
# Num_of_Loan                   int64
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment      float64
# Changed_Credit_Limit        float64
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age          float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# ...

# %%
# replace blanks into NaN values
df['Amount_invested_monthly'] = df['Amount_invested_monthly'].replace('', float('nan'))

# %%
# change Changed_Credit_Limit into float type
df['Amount_invested_monthly'] = df['Amount_invested_monthly'].astype(float)

# %%
df[df['Amount_invested_monthly'].isnull()]
# Out:
#             ID Customer_ID     Month             Name   Age        SSN  \
# 18      0x161c  CUS_0x2dbc     March           Langep  34.0  486853974
# 23      0x1621  CUS_0x2dbc    August           Langep  34.0  486853974
# 28      0x162a  CUS_0xb891       May           Jasond  55.0   72316145
# 60      0x165a  CUS_0x5407       May             Annk  30.0  500926408
# 61      0x165b  CUS_0x5407      June             Annk  30.0  500926408
# ...        ...         ...       ...              ...   ...        ...
# 99925  0x25f7f  CUS_0x2654      June              enj  38.0  647678889
# 99951  0x25fa5  CUS_0x51b3    August            Ryana  33.0  837859800
# 99961  0x25fb7  CUS_0x372c  February  Lucia Mutikanik  19.0  340857301
# 99973  0x25fc7   CUS_0xf16      June   Maria Sheahanb  45.0  868702218
# 99974  0x25fc8   CUS_0xf16      July   Maria Sheahanb  45.0  868702218
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
customer_id1 = df[(df['Amount_invested_monthly'].isna())]['Customer_ID'].values

# groupby Customer_ID and interpolate Amount_invested_monthly values 
df['Amount_invested_monthly'] = df.groupby('Customer_ID')['Amount_invested_monthly'].transform(
    lambda x: x.interpolate(method='index', limit_direction='both') if x.count() > 1 else x)

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name   Age        SSN Occupation  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh  23.0  821000265  Scientist
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821000265  Scientist
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  23.0  821000265  Scientist
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh  23.0  821000265  Scientist
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh  23.0  821000265  Scientist
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh  23.0  821000265  Scientist
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh  23.0  821000265  Scientist
# 7  0x1609   CUS_0xd40    August    Aaron Maashoh  23.0  821000265  Scientist
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj  28.0    4075839    Teacher
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj  28.0    4075839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %%
df['Amount_invested_monthly'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Payment_behaviour

# %%
df[df['Payment_Behaviour'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []

# %%
# replace blanks into NaN values
df['Payment_Behaviour'] = df['Payment_Behaviour'].replace('',np.nan)

# %%
def customer_payment(series):
    mode_values = series.dropna().mode()
    if mode_values.empty:
        return np.nan
    return mode_values.iloc[0]

# %%
payment_mode = df.groupby('Customer_ID')['Payment_Behaviour'].transform(customer_payment) 

df['Payment_Behaviour'] = df['Payment_Behaviour'].fillna(payment_mode)

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name   Age        SSN Occupation  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh  23.0  821000265  Scientist
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh  23.0  821000265  Scientist
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  23.0  821000265  Scientist
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh  23.0  821000265  Scientist
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh  23.0  821000265  Scientist
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh  23.0  821000265  Scientist
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh  23.0  821000265  Scientist
# 7  0x1609   CUS_0xd40    August    Aaron Maashoh  23.0  821000265  Scientist
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj  28.0    4075839    Teacher
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj  28.0    4075839    Teacher
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# ...

# %%
df['Payment_Behaviour'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Monthly_Balance

# %%
df.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                         float64
# SSN                           int64
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts           float64
# Num_Credit_Card             float64
# Interest_Rate               float64
# Num_of_Loan                   int64
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment      float64
# Changed_Credit_Limit        float64
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age          float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly     float64
# Payment_Behaviour            object
# ...

# %%
df['Outstanding_Debt'] = df['Outstanding_Debt'].astype(float)
df['Annual_Income'] = df['Annual_Income'].astype(float)

# %%
df['Monthly_Balance'] = df['Monthly_Balance'].str.replace(r'^(__-333333333333333333333333333__)$','',regex = True)

# %%
df['Monthly_Balance'] = df['Monthly_Balance'].replace('', float('nan'))

# %%
df['Monthly_Balance'] = df['Monthly_Balance'].astype(float)

# %%
df[df['Monthly_Balance'].isnull()]
# Out:
#             ID Customer_ID     Month            Name   Age        SSN  \
# 197     0x1727  CUS_0xa5f9      June           Rickt  34.0  189095267
# 314     0x17d8  CUS_0x571f     March  Emily Flitterl  19.0  397289675
# 388     0x1846  CUS_0x9b3c       May       Scheydere  43.0  224487837
# 456     0x18ae  CUS_0x9d78   January     Tim Hepherp  21.0  423776457
# 457     0x18af  CUS_0x9d78  February     Tim Hepherp  21.0  423776457
# ...        ...         ...       ...             ...   ...        ...
# 99995  0x25fe9  CUS_0x942c     April           Nicks  25.0   78735990
# 99996  0x25fea  CUS_0x942c       May           Nicks  25.0   78735990
# 99997  0x25feb  CUS_0x942c      June           Nicks  25.0   78735990
# 99998  0x25fec  CUS_0x942c      July           Nicks  25.0   78735990
# 99999  0x25fed  CUS_0x942c    August           Nicks  25.0   78735990
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
customer_id1 = df[(df['Monthly_Balance'].isna())]['Customer_ID'].values

# groupby Customer_ID and interpolate Monthly_Balance values 
df['Monthly_Balance'] = df.groupby('Customer_ID')['Monthly_Balance'].transform(
    lambda x: x.interpolate(method='index', limit_direction='both') if x.count() > 1 else x)

# %%
df[df['Monthly_Balance'].isnull()]
# Out:
#             ID Customer_ID     Month               Name   Age        SSN  \
# 98304  0x25602  CUS_0xb3d7   January  Greg Roumeliotisw  19.0  901771325
# 98305  0x25603  CUS_0xb3d7  February  Greg Roumeliotisw  19.0  901771325
# 98306  0x25604  CUS_0xb3d7     March  Greg Roumeliotisw  19.0  901771325
# 98307  0x25605  CUS_0xb3d7     April  Greg Roumeliotisw  19.0  901771325
# 98308  0x25606  CUS_0xb3d7       May  Greg Roumeliotisw  19.0  901771325
# ...        ...         ...       ...                ...   ...        ...
# 99995  0x25fe9  CUS_0x942c     April              Nicks  25.0   78735990
# 99996  0x25fea  CUS_0x942c       May              Nicks  25.0   78735990
# 99997  0x25feb  CUS_0x942c      June              Nicks  25.0   78735990
# 99998  0x25fec  CUS_0x942c      July              Nicks  25.0   78735990
# 99999  0x25fed  CUS_0x942c    August              Nicks  25.0   78735990
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
numeric_columns = df.select_dtypes(include=['number'])

correlation_matrix = numeric_columns.corr()

plt.figure(figsize=(10, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation of Factors vs Monthly Balance')
plt.show()

# %% [markdown]
# #### Fill NaNs based on Monthly inhand salary

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='most_frequent')

df['Monthly_Balance'] = imputer.fit_transform(df[['Monthly_Balance']])

# %%
monthly_balance_mode = df.groupby('Monthly_Inhand_Salary')['Monthly_Balance'].transform(customer_payment) 

df['Monthly_Balance'] = df['Monthly_Balance'].fillna(monthly_balance_mode)

# %%
df[df['Monthly_Balance'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []

# %% [markdown]
# # II, Data Analysis

# %%
num_vars = df.select_dtypes(include = ['number'])
sns.set(style='whitegrid')
fig, axes = plt.subplots(5, 4, figsize =(18,18), sharey = True)

axes = axes.flatten()

for i, feature in enumerate(num_vars.columns):
    sns.violinplot(x = df[feature], ax =axes[i], color = np.random.rand(3,))
    axes[i].set_title(f'Feature {feature}')
    
    
plt.tight_layout()
plt.show()

# %%
df['Age'].describe()
# Out:
# count    100000.000000
# mean         33.600720
# std          10.767532
# min          14.000000
# 25%          25.000000
# 50%          33.000000
# 75%          42.000000
# max          56.000000
# Name: Age, dtype: float64

# %%
df['Annual_Income'].describe()
# Out:
# count    1.000000e+05
# mean     1.764157e+05
# std      1.429618e+06
# min      7.005930e+03
# 25%      1.945750e+04
# 50%      3.757861e+04
# 75%      7.279092e+04
# max      2.419806e+07
# Name: Annual_Income, dtype: float64

# %%
def replace_Annual_Income(group):
    min_annual_income = group['Annual_Income'].min()
    max_annual_income = group['Annual_Income'].max()
    group['Annual_Income'] = group['Annual_Income'].apply(lambda x: min_annual_income if x > 0.2e+06 else x)
    return group
    
# Apply function to DataFrame using groupby and transform

df = df.groupby('Customer_ID').apply(replace_Annual_Income).reset_index(drop = True)
# Out:
# C:\Users\t\AppData\Local\Temp\ipykernel_8212\560226168.py:9: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df = df.groupby('Customer_ID').apply(replace_Annual_Income).reset_index(drop = True)

# %%
df['Annual_Income'].describe()
# Out:
# count    100000.000000
# mean      50505.123449
# std       38299.422093
# min        7005.930000
# 25%       19342.972500
# 50%       36999.705000
# 75%       71683.470000
# max      179987.280000
# Name: Annual_Income, dtype: float64

# %%
df['Interest_Rate'].describe()
# Out:
# count    100000.00000
# mean         14.53208
# std           8.74133
# min           1.00000
# 25%           7.00000
# 50%          13.00000
# 75%          20.00000
# max          34.00000
# Name: Interest_Rate, dtype: float64

# %%
df['Num_Credit_Card'].describe()
# Out:
# count    100000.000000
# mean          5.533600
# std           2.070313
# min           0.000000
# 25%           4.000000
# 50%           5.000000
# 75%           7.000000
# max          11.000000
# Name: Num_Credit_Card, dtype: float64

# %%
df['Num_of_Delayed_Payment'].describe()
# Out:
# count    100000.000000
# mean         30.875625
# std         222.894520
# min          -3.000000
# 25%           9.000000
# 50%          14.000000
# 75%          18.000000
# max        4397.000000
# Name: Num_of_Delayed_Payment, dtype: float64

# %% [markdown]
# <https://www.cnbc.com/select/what-happens-when-you-miss-a-credit-card-payment/>
# #### It seems like 30 days is the maximum in general

# %%
def replace_Delay_Payment(group):
    min_delay_payment = group['Num_of_Delayed_Payment'].min()
    max_delay_payment = group['Num_of_Delayed_Payment'].max()
    group['Num_of_Delayed_Payment'] = group['Num_of_Delayed_Payment'].apply(lambda x: min_delay_payment if x > 1 or x < 30 else x)
    return group
    
# Apply function to DataFrame using groupby and transform

df = df.groupby('Customer_ID').apply(replace_Delay_Payment).reset_index(drop = True)
# Out:
# C:\Users\t\AppData\Local\Temp\ipykernel_8212\600456240.py:9: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df = df.groupby('Customer_ID').apply(replace_Delay_Payment).reset_index(drop = True)

# %%
df['Num_of_Delayed_Payment'].describe()
# Out:
# count    100000.000000
# mean         11.619840
# std           6.286432
# min          -3.000000
# 25%           7.000000
# 50%          12.000000
# 75%          16.000000
# max          25.000000
# Name: Num_of_Delayed_Payment, dtype: float64

# %%
df['Num_Bank_Accounts'].value_counts()
# Out:
#  6.0     13152
#  7.0     12984
#  8.0     12928
#  4.0     12360
#  5.0     12344
#  3.0     12008
#  9.0      5520
#  10.0     5320
#  1.0      4560
#  2.0      4384
#  0.0      4384
# -1.0        32
#  11.0       24
# Name: Num_Bank_Accounts, dtype: int64

# %%
df['Num_Bank_Accounts'] = df['Num_Bank_Accounts'].abs()

# %%
df['Num_Bank_Accounts'].value_counts()
# Out:
# 6.0     13152
# 7.0     12984
# 8.0     12928
# 4.0     12360
# 5.0     12344
# 3.0     12008
# 9.0      5520
# 10.0     5320
# 1.0      4592
# 2.0      4384
# 0.0      4384
# 11.0       24
# Name: Num_Bank_Accounts, dtype: int64

# %%
df['Num_of_Loan'].describe()
# Out:
# count    100000.000000
# mean          3.532880
# std           2.446356
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           5.000000
# max           9.000000
# Name: Num_of_Loan, dtype: float64

# %%
df['Num_of_Loan'].describe()
# Out:
# count    100000.000000
# mean          3.532880
# std           2.446356
# min           0.000000
# 25%           2.000000
# 50%           3.000000
# 75%           5.000000
# max           9.000000
# Name: Num_of_Loan, dtype: float64

# %%
df['Total_EMI_per_month'].describe()
# Out:
# count    100000.000000
# mean       1403.118217
# std        8306.041270
# min           0.000000
# 25%          30.306660
# 50%          69.249473
# 75%         161.224249
# max       82331.000000
# Name: Total_EMI_per_month, dtype: float64

# %%
def replace_Total_EMI_per_month(group):
    min_emi = group['Total_EMI_per_month'].min()
    max_emi = group['Total_EMI_per_month'].max()
    group['Total_EMI_per_month'] = group['Total_EMI_per_month'].apply(lambda x: min_emi if x < 1 or x > 400 else x)
    return group
    
# Apply function to DataFrame using groupby and transform
df = df.groupby('Customer_ID').apply(replace_Total_EMI_per_month).reset_index(drop = True)
# Out:
# C:\Users\t\AppData\Local\Temp\ipykernel_8212\2536413227.py:8: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df = df.groupby('Customer_ID').apply(replace_Total_EMI_per_month).reset_index(drop = True)

# %%
df['Total_EMI_per_month'].describe()
# Out:
# count    100000.000000
# mean         96.315701
# std          97.000702
# min           0.000000
# 25%          28.125728
# 50%          64.016009
# 75%         138.079727
# max        1042.674209
# Name: Total_EMI_per_month, dtype: float64

# %%
df['Amount_invested_monthly'].describe()
# Out:
# count    100000.000000
# mean        195.888840
# std         198.056716
# min           0.000000
# 25%          73.120365
# 50%         129.785283
# 75%         238.081272
# max        1977.326102
# Name: Amount_invested_monthly, dtype: float64

# %%
def replace_Amount_invested_monthly(group):
    min_amount_invested_monthly = group['Total_EMI_per_month'].min()
    max_amount_invested_monthly = group['Total_EMI_per_month'].max()
    group['Total_EMI_per_month'] = group['Total_EMI_per_month'].apply(lambda x: min_amount_invested_monthly if x < 1 or x > 800 else x)
    return group
    
# Apply function to DataFrame using groupby and transform
df = df.groupby('Customer_ID').apply(replace_Amount_invested_monthly).reset_index(drop = True)
# Out:
# C:\Users\t\AppData\Local\Temp\ipykernel_8212\1627871057.py:8: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df = df.groupby('Customer_ID').apply(replace_Amount_invested_monthly).reset_index(drop = True)

# %%
df['Amount_invested_monthly'].describe()
# Out:
# count    100000.000000
# mean        195.888840
# std         198.056716
# min           0.000000
# 25%          73.120365
# 50%         129.785283
# 75%         238.081272
# max        1977.326102
# Name: Amount_invested_monthly, dtype: float64

# %%
num_vars = df.select_dtypes(include=['number'])
sns.set(style='whitegrid')  
fig, axes = plt.subplots(5, 4, figsize=(18, 18), sharey=True) 

axes = axes.flatten()

for i, feature in enumerate(num_vars.columns):
    sns.violinplot(x=df[feature], ax=axes[i], color=np.random.rand(3,))  
    axes[i].set_title(f'Feature {feature}')  


plt.tight_layout()

plt.show()

# %% [markdown]
# # III, Exploratory Data Analysis
